# %% [markdown]
# <a href="https://colab.research.google.com/github/Narae-210/Python-self-study/blob/main/%EA%B3%A0%ED%8C%8C%EC%8A%A4%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
webpage = requests.get("https://www.koreapas.com/bbs/zboard.php?id=tiger")
print(webpage.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
#
# <meta content="text/html; charset=euc-kr" http-equiv="Content-Type" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
#
#
#
#
# 	<title>È£·©ÀÌ±¤Àå</title>
# <meta property="og:title" content="È£·©ÀÌ±¤Àå °Ô½ÃÆÇ" />
# <meta property="og:url" content="https://www.koreapas.com/bbs/zboard.php?id=tiger" />
# <meta property="og:description" content="°í·Á´ëÇÐ±³ °íÆÄ½º" />
# <meta property="og:image" content="https://www.koreapas.com/social_koreapas.png">
# <link rel="image_src" href="https://www.koreapas.com/social_koreapas.png" />
# <meta property="og:image:width" content="640" />
# <meta property="og:image:height" content="320" />
#
#
#
#
#
# 	<link href='../m/Icon-192.png?v=20170925' rel='icon' type='image/png' />
# <link href='../m/Icon-192.png?v=20170925' rel='shortcut icon' type='image/png' />
# <link href='../m/Icon-128.png?v=20170925' rel='apple-touch-icon'  type='image/png'/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
webpage = requests.get("https://www.koreapas.com/bbs/zboard.php?id=tiger")
soup = BeautifulSoup(webpage.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>호랭이광장</title>
# <meta content="호랭이광장 게시판" property="og:title">
# <meta content="https://www.koreapas.com/bbs/zboard.php?id=tiger" property="og:url"/>
# <meta content="고려대학교 고파스" property="og:description"/>
# <meta content="https://www.koreapas.com/social_koreapas.png" property="og:image"/>
# <link href="https://www.koreapas.com/social_koreapas.png" rel="image_src"/>
# <meta content="640" property="og:image:width">
# <meta content="320" property="og:image:height"/>
# <link href="../m/Icon-192.png?v=20170925" rel="icon" type="image/png"/>
# <link href="../m/Icon-192.png?v=20170925" rel="shortcut icon" type="image/png"/>
# <link href="../m/Icon-128.png?v=20170925" rel="apple-touch-icon" type="image/png"/>
# <link href="../m/favicon.ico?v=20170925" rel="shortcut icon"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
webpage = requests.get("https://www.koreapas.com/bbs/zboard.php?id=tiger")
soup = BeautifulSoup(webpage.content, 'html.parser')
print(soup.p)
# Out:
# None

# %%
import requests
webpage = requests.get('https://www.koreapas.com/bbs/best_pc.php?back=1')
print(webpage.text)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml" lang="ko" xml:lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr" />
# <meta http-equiv="Content-Script-Type" content="text/javascript" />
# <meta http-equiv="Content-Style-Type" content="text/css" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
# <meta name="title" content="°í·Á´ëÇÐ±³ °íÆÄ½º"/>
# <meta property="og:title" content="°í·Á´ëÇÐ±³ °íÆÄ½º"/>
# <meta name="description" content="°í´ë ÀçÇÐ»ý,Á¹¾÷»ýÀÌ ÇÔ²²ÇÏ´Â ¿Â¶óÀÎ Ä¿¹Â´ÏÆ¼ÀÔ´Ï´Ù."/>
# <meta property="og:description" content="°í´ë ÀçÇÐ»ý,Á¹¾÷»ýÀÌ ÇÔ²²ÇÏ´Â ¿Â¶óÀÎ Ä¿¹Â´ÏÆ¼ÀÔ´Ï´Ù."/>
# <meta name="keywords" content="°í·Á´ë,°í´ë,¹ÎÁ·°í´ë,korea univ,°íÆã,°íÆÄ½º,koreapas">
# <meta property="og:image" content="https://www.koreapas.com/bbs/koreapas_kakao4.png">
# ...

# %% [markdown]
# 여기부터 **당근마켓** 으로 했엉 !

# %%
from bs4 import BeautifulSoup
webpage = requests.get('https://www.daangn.com/hot_articles')
soup = BeautifulSoup(webpage.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/hot_articles" rel="canonical"/>
# <title>당근마켓 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="description">
# <link href="당근마켓" rel="author"/>
# <meta content="https://www.daangn.com/hot_articles" property="og:url">
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" property="og:title">
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# ...

# %%
print(soup.p)
# Out:
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>

# %%
print(soup.p.string)
# Out:
# 당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!

# %%
print(soup.h1)
# Out:
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a> </h1>

# %%
for child in soup.ul.children:
    print(child)
# Out:
# <li>
# <a class="menu-anchor" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg"/>
# <span>App Store</span>
# </a> </li>
#
#
# <li>
# <a class="menu-anchor" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg"/>
# <span>Google Play</span>
# </a> </li>

# %%
for parent in soup.ul.parents:
    print(parent)
# Out:
# <div class="fixed-download-wrapper">
# <input class="fixed-checkbox" id="fixed-menu-checkbox" type="checkbox"/>
# <label class="fixed-label" for="fixed-menu-checkbox">
#           다운로드
#           <svg class="menu-icon-svg" fill="none" height="7" viewbox="0 0 12 7" width="12" xmlns="http://www.w3.org/2000/svg">
# <path d="M1 1L6 6L11 1" stroke="#4D5159" strokelinecap="round" strokelinejoin="round" strokewidth="1.5"></path>
# </svg>
# </label>
# <ul class="fixed-menu-ul">
# <li>
# <a class="menu-anchor" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg"/>
# <span>App Store</span>
# </a> </li>
# <li>
# ...

# %%
for d in soup.div.children:
    print(d)
# Out:
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg"/>
# </a> </h1>
#
#
# <section id="fixed-bar-search">
# <div class="search-input-wrap">
# <span class="sr-only">검색</span>
# <input class="fixed-search-input" id="header-search-input" name="header-search-input" placeholder="동네 이름, 물품명 등을 검색해보세요!" type="text"/>
# <button id="header-search-button">
# <img alt="Search" class="fixed-search-icon" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg"/>
# </button>
# </div>
# </section>
#
#
# <section class="fixed-bar-menu">
# <div class="fixed-download-wrapper">
# <input class="fixed-checkbox" id="fixed-menu-checkbox" type="checkbox"/>
# ...

# %%
print(soup.find_all("h2"))
# Out:
# [<h2 class="card-title">신일 이동식 에어콘 !</h2>, <h2 class="card-title">셰퍼 듀얼 쿨링 넥밴드 선풍기(새제품)</h2>, <h2 class="card-title">낙시용품</h2>, <h2 class="card-title">스토케 트립트랩 + 베이비세트</h2>, <h2 class="card-title">위니아 창문형 에어컨</h2>, <h2 class="card-title">스텐 4단 선반</h2>, <h2 class="card-title">낙시용품</h2>, <h2 class="card-title">삼성55인치 led tv 팝니다</h2>, <h2 class="card-title">캠핑의자</h2>, <h2 class="card-title">pxg 골프모자 썬캡 새상품</h2>, <h2 class="card-title">신일 이동식에어컨 저렴하게 팝니다.</h2>, <h2 class="card-title">캐리어 스텐드 에어컨 + 실외기</h2>, <h2 class="card-title">마이크로 킥보드 맥시</h2>, <h2 class="card-title">타이틀리스트 골프공</h2>, <h2 class="card-title">코스트코 고릴라랙 5단 철제 선반</h2>, <h2 class="card-title">냉장고</h2>, <h2 class="card-title">전자레인지 팝니다</h2>, <h2 class="card-title">풀박 에어팟 프로 </h2>, <h2 class="card-title">데스크탑+모니터2 쓰실 분~~</h2>, <h2 class="card-title">접이식 캠핑의자</h2>, <h2 class="card-title">냉장고 팔아요</h2>, <h2 class="card-title">삼성제습기11리터 팝니다</h2>, <h2 class="card-title">해남 밤고구마</h2>, <h2 class="card-title">166헤르츠 모니터</h2>, <h2 cla
# ...

# %% [markdown]
# http://hleecaster.com/python-web-crawling-with-beautifulsoup/
#
# 정규식부터는 내일 해보고,, 일단 교수님께 보내자,,,, !
