# %% [markdown]
# <a href="https://colab.research.google.com/github/Narae-210/Python-self-study/blob/main/%EA%B3%A0%ED%8C%8C%EC%8A%A4%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **고파스 크롤링!!!**

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.koreapas.com/bbs/zboard.php?id=tiger")  

bsObject = BeautifulSoup(html, "html.parser") 


print(bsObject) # 웹 문서 전체가 출력
# Out:
# <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>호랭이광장</title>
# <meta content="호랭이광장 게시판" property="og:title">
# <meta content="https://www.koreapas.com/bbs/zboard.php?id=tiger" property="og:url"/>
# <meta content="고려대학교 고파스" property="og:description"/>
# <meta content="https://www.koreapas.com/social_koreapas.png" property="og:image"/>
# <link href="https://www.koreapas.com/social_koreapas.png" rel="image_src"/>
# <meta content="640" property="og:image:width">
# <meta content="320" property="og:image:height"/>
# <link href="../m/Icon-192.png?v=20170925" rel="icon" type="image/png"/>
# <link href="../m/Icon-192.png?v=20170925" rel="shortcut icon" type="image/png"/>
# <link href="../m/Icon-128.png?v=20170925" rel="apple-touch-icon" type="image/png"/>
# <link href="../m/favicon.ico?v=20170925" rel="shortcut icon"/>
# ...

# %%
#타이틀 가져오기

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.koreapas.com/bbs/zboard.php?id=tiger")
bsObject = BeautifulSoup(html, "html.parser")

print(bsObject.head.title)
# Out:
# <title>호랭이광장</title>

# %%
#메타데이터 내용 가져오기

for meta in bsObject.head.find_all('meta'):
    print(meta.get('content'))
# Out:
# text/html; charset=euc-kr
# IE=edge,chrome=1
# 호랭이광장 게시판
# https://www.koreapas.com/bbs/zboard.php?id=tiger
# 고려대학교 고파스
# https://www.koreapas.com/social_koreapas.png
# 640
# 320
# ../m/Icon-144.png?v=20170925

# %%
#원하는 태그 가져오기

# print (bsObject.head.find("meta", {"name":"description"}).get('content'))

#name이 description인 것들 가져오기!

print (bsObject.head.find("meta", {"name":"description"}))
# Out:
# None

# %%
print (bsObject.head.find("meta", {"name":"description"}).get('content'))

# 왜 에러나지!?!!!!! 😥
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-64c5740b0797> in <module>()
# ----> 1 print (bsObject.head.find("meta", {"name":"description"}).get('content'))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.python.org/about")
bsObject = BeautifulSoup(html, "html.parser")


print (bsObject.head.find("meta", {"name":"description"}).get('content'))
# Out:
# The official home of the Python Programming Language

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.koreapas.com/bbs/zboard.php?id=tiger")
bsObject = BeautifulSoup(html, "html.parser")


print (bsObject.head.find("meta", {"name":"description"}).get('content'))

#헐! 고파스에서만 에러가 난다,,, 뭐지ㅠ,,,,ㅠㅠㅠㅠ
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ebec5057604a> in <module>()
#       7
#       8
# ----> 9 print (bsObject.head.find("meta", {"name":"description"}).get('content'))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
#모든링크의 텍스트, 주소

from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://www.koreapas.com/bbs/zboard.php?id=tiger")
bsObject = BeautifulSoup(html, "html.parser")

for link in bsObject.find_all('a'):
    print(link.text.strip(), link.get('href'))
# Out:
#  https://www.koreapas.com/bbs/main.php
# 호랭이광장 44 zboard.php?id=tiger
# HOT 게시물 best_pc.php?back=1
# 웃음·연재 114 zboard.php?id=gofun
# 정치·사회·이슈 17 zboard.php?id=edic
# 자유홍보 38 zboard.php?id=freead
# 공개일기장 zboard.php?id=opendiary
# 창업 3 zboard.php?id=vt
# 학생회 zboard.php?id=saad
# 고대뉴스 zboard.php?id=kutimes
# 새내기 맞이단 zboard.php?id=club
# 강의·필기·족보 2 zboard.php?id=kustudy
# 동아리 20 zboard.php?id=circle
# 스터디 18 zboard.php?id=study
# 사회봉사 zboard.php?id=kusso
# 꽈톡 298 dept.php
# 동물원 (반말) 2207 zboard.php?id=talk2
# 식물원 (존대) 199 zboard.php?id=mento
# 대학원 11 zboard.php?id=gra
# 연애상담 75 zboard.php?id=greenlight
# 미용·패션 26 zboard.php?id=pashion
# 주식·재테크 7 zboard.php?id=econo
# 리뷰 3 zboard.php?id=kfc
# 벼룩시장 49 zboard.php?id=kumarket
# 헌책방 10 zboard.php?id=book
# 복덕방 52 zboard.php?id=house
# 알바·과외 23 zboard.php?id=job
# 여행·해외 zboard.php?id=global
# 자취·요리·건강 2 zboard.php?id=ja
# 게임 1 zboard.php?id=enjoyus
# 스포츠 1 zboard.php?id=sports
# 연예·방송 zboard.php?id=live
# 문화교양 zboard.php?id=culture
# ...
